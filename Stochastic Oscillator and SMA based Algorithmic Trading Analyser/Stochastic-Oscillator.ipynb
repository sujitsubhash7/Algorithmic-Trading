# %%
# Initial imports
import os
import requests
import numpy as np
import pandas as pd
import hvplot.pandas
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
import matplotlib.pyplot as plt
from pathlib import Path

# %matplotlib inline

# %%
#Load .env environment variables
load_dotenv()
# Out:
# True

# %%
# Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")
# Verify that Alpaca key and secret were correctly loaded
print(f"Alpaca Key type: {type(alpaca_api_key)}")
print(f"Alpaca Secret Key type: {type(alpaca_secret_key)}")
# Out:
# Alpaca Key type: <class 'str'>
# Alpaca Secret Key type: <class 'str'>

# %%
# Create the Alpaca API object
alpaca = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2")

# %%
# Set the tickers
ticker = ["AMZN"]
# Set timeframe to one day ('1D') for the Alpaca API
timeframe = "1D"
# From Alpaca API
# The resolution of time window. 1Min, 5Min, 15Min, 1H, or 1D. If omitted, 
# 1Min for less than 7 days period, 15Min for less than 30 days, or otherwise 1D.

# Format start and end dates as ISO format for one year period
start = pd.Timestamp("2016-09-15", tz="America/New_York").isoformat()
end = pd.Timestamp("2021-09-15", tz="America/New_York").isoformat()

# Get closing prices for FB and TWTR from the last year
faangm_portfolio_df_ = alpaca.get_barset(
    ticker,
    timeframe,
    start = start,
    end = end,
    limit = 1000
).df

# Display sample data
faangm_portfolio_df_.head(10)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-6-f6794415b676> in <module>
#      17     start = start,
#      18     end = end,
# ---> 19     limit = 1000
#      20 ).df
#      21
#
# ~\.conda\envs\pyvizapimlenv\lib\site-packages\alpaca_trade_api\rest.py in get_barset(self, symbols, timeframe, limit, start, end, after, until)
#     511         if until is not None:
#     512             params['until'] = until
# --> 513         resp = self.data_get('/bars/{}'.format(timeframe), params)
#     514         return self.response_wrapper(resp, BarSet)
#     515
#
# ~\.conda\envs\pyvizapimlenv\lib\site-packages\alpaca_trade_api\rest.py in data_get(self, path, data, api_version)
#     191         base_url: URL = get_data_url()
#     192         return self._request(
# --> 193             'GET', path, data, base_url=base_url, api_version=api_version,
#     194         )
#     195
#
# ~\.conda\envs\pyvizapimlenv\lib\site-packages\alpaca_trade_api\rest.py in _request(self, method, path, data, base_url, api_version)
#     137         while retry >= 0:
#     138             try:
# --> 139                 return self._one_request(method, url, opts, retry)
#     140             except RetryException:
#     141                 retry_wait = self._retry_wait
#
# ~\.conda\envs\pyvizapimlenv\lib\site-packages\alpaca_trade_api\rest.py in _one_request(self, method, url, opts, retry)
#     158         resp = self._session.request(method, url, **opts)
#     159         try:
# --> 160             resp.raise_for_status()
#     161         except HTTPError as http_error:
#     162             # retry if we hit Rate Limit
#
# ~\.conda\envs\pyvizapimlenv\lib\site-packages\requests\models.py in raise_for_status(self)
#     951
#     952         if http_error_msg:
# --> 953             raise HTTPError(http_error_msg, response=self)
#     954
#     955     def close(self):
#
# HTTPError: 500 Server Error: Internal Server Error for url: https://data.alpaca.markets/v1/bars/1D?symbols=AMZN&limit=1000&start=2016-09-15T00%3A00%3A00-04%3A00&end=2021-09-15T00%3A00%3A00-04%3A00

# %%
#Create and empty DataFrame for closing prices
faangm_closing_return_df_ = pd.DataFrame()

# Fetch the closing prices of FB and TWTR
faangm_closing_return_df_["AMZN"] = faangm_portfolio_df_["AMZN"]["close"]

# Drop the time component of the date
faangm_closing_return_df_.index = faangm_closing_return_df_.index.date

# Display sample data
faangm_closing_return_df_.head(10)

# %%
faangm_closing_return_df_=pd.read_csv(Path("AMZN.csv"))
faangm_closing_return_df_.index = faangm_closing_return_df_["Unnamed: 0"]
faangm_closing_return_df_.drop(columns="Unnamed: 0", inplace=True)
faangm_closing_return_df_.head()
# Out:
#               AMZN
# Unnamed: 0
# 2017-09-26  938.59
# 2017-09-27  950.88
# 2017-09-28  956.40
# 2017-09-29  960.49
# 2017-10-02  958.79

# %%
# faangm_closing_return_df= faangm_closing_return_df_.copy()
# faangm_closing_return_df.head()

# k_period=14
# d_period=3
# short_window=5
# long_window=15

# faangm_closing_return_df["AMZN_k_period_min"] = faangm_closing_return_df["AMZN"].rolling(window=k_period).min()
# faangm_closing_return_df["AMZN_k_period_max"] = faangm_closing_return_df["AMZN"].rolling(window=k_period).max()
# faangm_closing_return_df["AMZN_k_component_fast"] =  100 * ((faangm_closing_return_df["AMZN"] - faangm_closing_return_df["AMZN_k_period_min"]) / (faangm_closing_return_df["AMZN_k_period_max"] - faangm_closing_return_df["AMZN_k_period_min"]))
                        
# #d_period=d_period
# faangm_closing_return_df["AMZN_d_component_slow"] = faangm_closing_return_df["AMZN_k_component_fast"].rolling(window=d_period).mean()
# #short_window = short_window
# faangm_closing_return_df["AMZN_sma_fast"] = faangm_closing_return_df["AMZN"] .rolling(window=short_window).mean()
                        
# #long_window = long_window
# faangm_closing_return_df["AMZN_sma_slow"] = faangm_closing_return_df["AMZN"] .rolling(window=long_window).mean()
                        
# faangm_closing_return_df = faangm_closing_return_df.dropna()
# faangm_closing_return_df

# %% [markdown]
# ## Generating the Features and Target Sets
#
# ### Creating the Features Set

# %%
# Parameter sweep step
# Run this step only for re-discovery of Parameters

k_period_list=[]
d_period_list=[]
short_window_list=[]
long_window_list=[]
k_80_list=[]
k_20_list=[]
annual_return_list=[]
cumulative_returns_list=[]
annual_volatility_list=[]
sharpe_ratio_list=[]
sortino_ratio_list=[]



for k_period in range(12,21): # (3,26)
    for d_period in range(3,8): #(3,15)
        for short_window in range(5,11): #(2,20)
            for long_window in range(10,16): #(4,50)
                for k_80 in range(80,95): #(65,98)
                    for k_20 in range(20,29): #(5,35)
                        
                      
                        faangm_closing_return_df= faangm_closing_return_df_.copy()
                        
                        
                        #k_period=k_period
                        faangm_closing_return_df["AMZN_k_period_min"] = faangm_closing_return_df["AMZN"].rolling(window=k_period).min()
                        faangm_closing_return_df["AMZN_k_period_max"] = faangm_closing_return_df["AMZN"].rolling(window=k_period).max()
                        faangm_closing_return_df["AMZN_k_component_fast"] =  100 * ((faangm_closing_return_df["AMZN"] - faangm_closing_return_df["AMZN_k_period_min"]) / (faangm_closing_return_df["AMZN_k_period_max"] - faangm_closing_return_df["AMZN_k_period_min"]))
                        
                        #d_period=d_period
                        faangm_closing_return_df["AMZN_d_component_slow"] = faangm_closing_return_df["AMZN_k_component_fast"].rolling(window=d_period).mean()
                        
                        #short_window = short_window
                        faangm_closing_return_df["AMZN_sma_fast"] = faangm_closing_return_df["AMZN"] .rolling(window=short_window).mean()
                        
                        #long_window = long_window
                        faangm_closing_return_df["AMZN_sma_slow"] = faangm_closing_return_df["AMZN"] .rolling(window=long_window).mean()
                        
                        faangm_closing_return_df = faangm_closing_return_df.dropna()
                        
                        
                        prices= faangm_closing_return_df["AMZN"].array
                        k= faangm_closing_return_df["AMZN_k_component_fast"].array
                        d= faangm_closing_return_df["AMZN_d_component_slow"].array
                        sma_fast= faangm_closing_return_df["AMZN_sma_fast"].array
                        sma_slow= faangm_closing_return_df["AMZN_sma_slow"].array
                        
                        buy_price = []
                        sell_price = []
                        stoch_signal = []
                        signal = 0
                        
                        
                        for i in range(len(prices)):
                            if (k[i] < k_20 and d[i] < k_20 and k[i] < d[i])  or ((sma_fast[i] > sma_slow[i]) and (sma_fast[i-1] <= sma_slow[i-1])) :
                                if signal != 1:
                                    buy_price.append(prices[i])
                                    sell_price.append(np.nan)
                                    signal = 1                
                                    stoch_signal.append(signal)
                                else:
                                    buy_price.append(np.nan)
                                    sell_price.append(np.nan)
                                    stoch_signal.append(0)
                            elif (k[i] > k_80 and d[i] > k_80 and k[i] > d[i]) or ((sma_fast[i] < sma_slow[i]) and (sma_fast[i-1] >= sma_slow[i-1])):
                                if signal != -1:
                                    buy_price.append(np.nan)
                                    sell_price.append(prices[i])
                                    signal = -1                
                                    stoch_signal.append(signal)
                                else:
                                    buy_price.append(np.nan)
                                    sell_price.append(np.nan)
                                    stoch_signal.append(0)
                            else:
                                buy_price.append(np.nan)
                                sell_price.append(np.nan)
                                stoch_signal.append(0)
                                
                                
#                         buy_price, sell_price, stoch_signal = implement_stoch_strategy(faangm_closing_return_df["AMZN"], 
#                                                                faangm_closing_return_df["AMZN_k_component_fast"], 
#                                                                faangm_closing_return_df["AMZN_d_component_slow"],
#                                                               faangm_closing_return_df["AMZN_sma_fast"],
#                                                               faangm_closing_return_df["AMZN_sma_slow"])

                        faangm_closing_return_df["AMZN_stoch_oscl_exit"]= stoch_signal
                        faangm_closing_return_df["AMZN_stoch_oscl_signal"]= faangm_closing_return_df["AMZN_stoch_oscl_exit"].cumsum()
                        # faangm_closing_return_df["buy_price"] = buy_price
                        # faangm_closing_return_df["sell_price"] = sell_price
                        faangm_closing_return_df["%K_80"]= k_80
                        faangm_closing_return_df["%K_20"]= k_20
                        
                        
                        
                        
                        # Drop all NaN values from the DataFrame
                        faangm_closing_return_df = faangm_closing_return_df.dropna()

                        # Set initial capital
                        initial_capital = float(1100000)

                        # Set the share size
                        share_size = 500

                        # Take a 500 share position where the dual moving average crossover is 1 (sma_fast is greater than sma_slow)
                        faangm_closing_return_df['AMZN_position'] = share_size * faangm_closing_return_df['AMZN_stoch_oscl_signal']

                        # Find the points in time where a 500 share position is bought or sold
                        faangm_closing_return_df['AMZN_entry_exit_position'] = faangm_closing_return_df['AMZN_position'].diff()

                        # Multiply share price by entry/exit positions and get the cumulatively sum
                        faangm_closing_return_df['AMZN_portfolio_holdings'] = faangm_closing_return_df['AMZN'] * faangm_closing_return_df['AMZN_entry_exit_position'].cumsum()

                        # Subtract the initial capital by the portfolio holdings to get the amount of liquid cash in the portfolio
                        faangm_closing_return_df['AMZN_portfolio_cash'] = initial_capital - (faangm_closing_return_df['AMZN'] * faangm_closing_return_df['AMZN_entry_exit_position']).cumsum()

                        # Get the total portfolio value by adding the cash amount by the portfolio holdings (or investments)
                        faangm_closing_return_df['AMZN_portfolio_total'] = faangm_closing_return_df['AMZN_portfolio_cash'] + faangm_closing_return_df['AMZN_portfolio_holdings']

                        # Calculate the portfolio daily returns
                        faangm_closing_return_df['AMZN_portfolio_daily_returns'] = faangm_closing_return_df['AMZN_portfolio_total'].pct_change()

                        # Calculate the cumulative returns
                        faangm_closing_return_df['AMZN_portfolio_cumulative_returns'] = (1 + faangm_closing_return_df['AMZN_portfolio_daily_returns']).cumprod() - 1

                        # Drop all NaN values from the DataFrame
                        faangm_closing_return_df = faangm_closing_return_df.dropna()
                        
                        
                        
                        
                        k_period_list.append(k_period)
                        d_period_list.append(d_period)
                        short_window_list.append(short_window)
                        long_window_list.append(long_window)
                        k_80_list.append(k_80)
                        k_20_list.append(k_20)
                        
                        # Calculate cumulative return
                        cumulative_returns_list.append(faangm_closing_return_df['AMZN_portfolio_cumulative_returns'][-1])

                        # Calculate annualized return
                        annual_return_list.append( (faangm_closing_return_df['AMZN_portfolio_daily_returns'].mean() * 252) )

                        # Calculate annual volatility
                        annual_volatility_list.append( ( faangm_closing_return_df['AMZN_portfolio_daily_returns'].std() * np.sqrt(252) ))

                        # Calculate Sharpe Ratio
                        sharpe_ratio_list.append( ( faangm_closing_return_df['AMZN_portfolio_daily_returns'].mean() * 252) / ( faangm_closing_return_df['AMZN_portfolio_daily_returns'].std() * np.sqrt(252)))

                        # Calculate Downside Return
                        sortino_ratio_df = faangm_closing_return_df[['AMZN_portfolio_daily_returns']].copy()
                        sortino_ratio_df.loc[:,'downside_returns'] = 0

                        target = 0
                        mask = sortino_ratio_df['AMZN_portfolio_daily_returns'] < target
                        sortino_ratio_df.loc[mask, 'downside_returns'] = sortino_ratio_df['AMZN_portfolio_daily_returns']**2

                        # Calculate Sortino Ratio
                        down_stdev = np.sqrt(sortino_ratio_df['downside_returns'].mean()) * np.sqrt(252) # Annualizing
                        expected_return = sortino_ratio_df['AMZN_portfolio_daily_returns'].mean() * 252 # Annualizing
                        sortino_ratio = expected_return/down_stdev

                        sortino_ratio_list.append(sortino_ratio)




                
    


# Prepare DataFrame for metrics
# metrics = ['k_period','d_period','short_window','long_window','k_80','k_20','annual_return', 'cumulative_returns','annual_volatility','sharpe_ratio','sortino_ratio']

# columns = ['backtest']

# Initialize the DataFrame with index set to evaluation metrics and column as `Backtest` (just like PyFolio)
#portfolio_evaluation_df = pd.DataFrame(index=metrics, columns=columns)
AMZN_portfolio_evaluation_df = pd.DataFrame({ 'k_period': k_period_list ,
                                             'd_period': d_period_list ,
                                             'short_window': short_window_list ,
                                             'long_window': long_window_list ,
                                             'k_80': k_80_list ,
                                             'k_20': k_20_list ,
                                             'annual_return': annual_return_list ,
                                             'cumulative_returns': cumulative_returns_list ,
                                             'annual_volatility': annual_volatility_list,
                                             'sharpe_ratio': sharpe_ratio_list,
                                             'sortino_ratio': sortino_ratio_list })


AMZN_portfolio_evaluation_df.to_csv("param_sweep.csv")

AMZN_portfolio_evaluation_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3ecd821e1e17> in <module>
#      23
#      24
# ---> 25                         faangm_closing_return_df= faangm_closing_return_df_.copy()
#      26
#      27
#
# NameError: name 'faangm_closing_return_df_' is not defined

# %%
# The following are defined using param sweep mechanism and the value corresponding to the hightest sharpe Ratio is used
#Define K-Period
k_period = 17
#Define D-Period
d_period = 7
# Define a short window size
short_window = 10
# Define a long window size 
long_window = 12
#Define the overbought line
k_80 = 94
#Define the oversold line
k_20 = 25

# %%
# Stochastic Oscillator
# always lie between 0 to 100 due to its normalization function
# Overbought level is 80
# Oversold level is 20
# Can try out different levels for better backtestign results

# The Stochastic Oscillator comprises two main components: %K Line, and %D Line

# %K Line: a.k.a. the Fast Stochastic indicator
# The sole purpose of this line is to express the current state of the market (overbought or oversold)
# k_component = 100 * ((Today's CLOSING PRICE - k_period LOWEST PRICE) / (k_period HIGHEST PRICE - k_period LOWEST PRICE))

faangm_closing_return_df = faangm_closing_return_df_.copy()

#K-Period is defiend using param sweep mechanism and the value corresponding to the hightest sharpe Ratio is used


# Today's CLOSING PRICE
faangm_closing_return_df.head(10)

#faangm_closing_return_df["AMZN"] = faangm_closing_return_df["AMZN"].rolling(window=14).mean()

# k_period LOWEST PRICE
faangm_closing_return_df["AMZN_k_period_min"] = faangm_closing_return_df["AMZN"].rolling(window=k_period).min()

# k_period HIGHEST PRICE
faangm_closing_return_df["AMZN_k_period_max"] = faangm_closing_return_df["AMZN"].rolling(window=k_period).max()

# Calculate k_component
faangm_closing_return_df["AMZN_k_component_fast"] =  100 * ((faangm_closing_return_df["AMZN"] - faangm_closing_return_df["AMZN_k_period_min"]) / (faangm_closing_return_df["AMZN_k_period_max"] - faangm_closing_return_df["AMZN_k_period_min"]))



# %D Line: a.k.a. the Slow Stochastic indicator
# This is defined as the moving average of the %K line for a specified period. 
# It is also known as the smooth version of the %K line as the line graph of the %D line will look smoother than the %K line. 
# The standard setting of the %D line is 3 as the number of periods.
# D-Period is defiend using param sweep mechanism and the value corresponding to the hightest sharpe Ratio is used

# Calculate D-Component
faangm_closing_return_df["AMZN_d_component_slow"] = faangm_closing_return_df["AMZN_k_component_fast"].rolling(window=d_period).mean()


faangm_closing_return_df.head()
# Out:
#               AMZN  AMZN_k_period_min  AMZN_k_period_max  \
# Unnamed: 0
# 2017-09-26  938.59                NaN                NaN
# 2017-09-27  950.88                NaN                NaN
# 2017-09-28  956.40                NaN                NaN
# 2017-09-29  960.49                NaN                NaN
# 2017-10-02  958.79                NaN                NaN
#
#             AMZN_k_component_fast  AMZN_d_component_slow
# Unnamed: 0
# 2017-09-26                    NaN                    NaN
# 2017-09-27                    NaN                    NaN
# 2017-09-28                    NaN                    NaN
# 2017-09-29                    NaN                    NaN
# 2017-10-02                    NaN                    NaN

# %%
#Simple Movign avergaes

# short window size is defiend using param sweep mechanism and the value corresponding to the hightest sharpe Ratio is used

# faangm_closing_return_df["AMZN_sma_fast"]=0
# Create an SMA that uses short_window, and assign it to a new column named “sma_fast” for each security
faangm_closing_return_df["AMZN_sma_fast"] = faangm_closing_return_df["AMZN"] .rolling(window=short_window).mean()

# long window size is defiend using param sweep mechanism and the value corresponding to the hightest sharpe Ratio is used
#long_window = 12

# faangm_closing_return_df["AMZN_sma_slow"]=0
# Create an SMA that uses long_window, and assign it to a new columns named “sma_slow”
faangm_closing_return_df["AMZN_sma_slow"] = faangm_closing_return_df["AMZN"] .rolling(window=long_window).mean()

faangm_closing_return_df = faangm_closing_return_df.dropna()

faangm_closing_return_df.head()
# Out:
#                AMZN  AMZN_k_period_min  AMZN_k_period_max  \
# Unnamed: 0
# 2017-10-26   972.54             965.47            1008.99
# 2017-10-27  1100.99             966.34            1100.99
# 2017-10-30  1110.85             966.34            1110.85
# 2017-10-31  1105.67             966.34            1110.85
# 2017-11-01  1103.50             966.34            1110.85
#
#             AMZN_k_component_fast  AMZN_d_component_slow  AMZN_sma_fast  \
# Unnamed: 0
# 2017-10-26              16.245404              42.277520        987.306
# 2017-10-27             100.000000              44.712585        997.061
# 2017-10-30             100.000000              50.216924       1007.512
# 2017-10-31              96.415473              56.789303       1017.180
# 2017-11-01              94.913847              67.795536       1027.831
#
#             AMZN_sma_slow
# Unnamed: 0
# 2017-10-26     989.094167
# 2017-10-27     997.926667
# 2017-10-30    1007.075000
# 2017-10-31    1015.594167
# 2017-11-01    1023.690833

# %%
def implement_stoch_strategy(prices, k, d, sma_fast, sma_slow):    
    buy_price = []
    sell_price = []
    stoch_signal = []
    signal = 0
    

    for i in range(len(prices)):
        if (k[i] < k_20 and d[i] < k_20 and k[i] < d[i])  or ((sma_fast[i] > sma_slow[i]) and (sma_fast[i-1] <= sma_slow[i-1])) :
            if signal != 1:
                buy_price.append(prices[i])
                sell_price.append(np.nan)
                signal = 1                
                stoch_signal.append(signal)
            else:
                buy_price.append(np.nan)
                sell_price.append(np.nan)
                stoch_signal.append(0)
        elif (k[i] > k_80 and d[i] > k_80 and k[i] > d[i]) or ((sma_fast[i] < sma_slow[i]) and (sma_fast[i-1] >= sma_slow[i-1])):
            if signal != -1:
                buy_price.append(np.nan)
                sell_price.append(prices[i])
                signal = -1                
                stoch_signal.append(signal)
            else:
                buy_price.append(np.nan)
                sell_price.append(np.nan)
                stoch_signal.append(0)
        else:
            buy_price.append(np.nan)
            sell_price.append(np.nan)
            stoch_signal.append(0)
            
    return buy_price, sell_price, stoch_signal
            
buy_price, sell_price, stoch_signal = implement_stoch_strategy(faangm_closing_return_df["AMZN"], 
                                                               faangm_closing_return_df["AMZN_k_component_fast"], 
                                                               faangm_closing_return_df["AMZN_d_component_slow"],
                                                              faangm_closing_return_df["AMZN_sma_fast"],
                                                              faangm_closing_return_df["AMZN_sma_slow"])

faangm_closing_return_df["AMZN_stoch_oscl_exit"]= stoch_signal
faangm_closing_return_df["AMZN_stoch_oscl_signal"]= faangm_closing_return_df["AMZN_stoch_oscl_exit"].cumsum()
# faangm_closing_return_df["buy_price"] = buy_price
# faangm_closing_return_df["sell_price"] = sell_price
faangm_closing_return_df["%K_80"]= k_80
faangm_closing_return_df["%K_20"]= k_20

# Drop all NaN values from the DataFrame
faangm_closing_return_df = faangm_closing_return_df.dropna()

faangm_closing_return_df.to_csv("buysell.csv")

# Print the DataFrame
faangm_closing_return_df.head(25)
# Out:
#                AMZN  AMZN_k_period_min  AMZN_k_period_max  \
# Unnamed: 0
# 2017-10-26   972.54             965.47            1008.99
# 2017-10-27  1100.99             966.34            1100.99
# 2017-10-30  1110.85             966.34            1110.85
# 2017-10-31  1105.67             966.34            1110.85
# 2017-11-01  1103.50             966.34            1110.85
# 2017-11-02  1094.00             966.34            1110.85
# 2017-11-03  1111.55             966.34            1111.55
# 2017-11-06  1120.46             966.34            1120.46
# 2017-11-07  1123.14             966.34            1123.14
# 2017-11-08  1132.86             966.34            1132.86
# 2017-11-09  1129.00             966.34            1132.86
# 2017-11-10  1125.34             966.34            1132.86
# 2017-11-13  1129.21             966.34            1132.86
# 2017-11-14  1136.84             966.34            1136.84
# 2017-11-15  1127.09             972.54            1136.84
# 2017-11-16  1136.95             972.54            1136.95
# 2017-11-17  1129.87             972.54            1136.95
# 2017-11-20  1126.56            1094.00            1136.95
# 2017-11-21  1139.58            1094.00            1139.58
# 2017-11-22  1156.16            1094.00            1156.16
# 2017-11-24  1186.41            1094.00            1186.41
# 2017-11-27  1195.62            1094.00            1195.62
# 2017-11-28  1193.60            1111.55            1195.62
# 2017-11-29  1161.21            1120.46            1195.62
# 2017-11-30  1176.59            1123.14            1195.62
#
#             AMZN_k_component_fast  AMZN_d_component_slow  AMZN_sma_fast  \
# Unnamed: 0
# 2017-10-26              16.245404              42.277520        987.306
# 2017-10-27             100.000000              44.712585        997.061
# 2017-10-30             100.000000              50.216924       1007.512
# 2017-10-31              96.415473              56.789303       1017.180
# 2017-11-01              94.913847              67.795536       1027.831
# 2017-11-02              88.339907              75.205213       1038.571
# 2017-11-03             100.000000              85.130662       1051.435
# 2017-11-06             100.000000              97.095604       1066.847
# 2017-11-07             100.000000              97.095604       1081.561
# 2017-11-08             100.000000              97.095604       1097.556
# 2017-11-09              97.681960              97.276531       1113.202
# 2017-11-10              95.484026              97.357985       1115.637
# 2017-11-13              97.808071              98.710580       1117.473
# 2017-11-14             100.000000              98.710580       1120.590
# 2017-11-15              94.065733              97.862827       1122.949
# 2017-11-16             100.000000              97.862827       1127.244
# 2017-11-17              95.693693              97.247640       1129.076
# 2017-11-20              75.809080              94.122943       1129.686
# 2017-11-21             100.000000              94.768082       1131.330
# 2017-11-22             100.000000              95.081215       1133.660
# 2017-11-24             100.000000              95.081215       1139.401
# 2017-11-27             100.000000              95.928968       1146.429
# 2017-11-28              97.597240              95.585716       1152.868
# 2017-11-29              54.217669              89.660570       1155.305
# 2017-11-30              73.744481              89.365627       1160.255
#
#             AMZN_sma_slow  AMZN_stoch_oscl_exit  AMZN_stoch_oscl_signal  \
# Unnamed: 0
# 2017-10-26     989.094167                    -1                      -1
# 2017-10-27     997.926667                     0                      -1
# 2017-10-30    1007.075000                     1                       0
# 2017-10-31    1015.594167                     0                       0
# 2017-11-01    1023.690833                     0                       0
# 2017-11-02    1030.775000                     0                       0
# 2017-11-03    1040.321667                     0                       0
# 2017-11-06    1051.476667                    -1                      -1
# 2017-11-07    1063.162500                     0                      -1
# 2017-11-08    1077.039167                     0                      -1
# 2017-11-09    1089.789167                     0                      -1
# 2017-11-10    1102.491667                     0                      -1
# 2017-11-13    1115.547500                     0                      -1
# 2017-11-14    1118.535000                     0                      -1
# 2017-11-15    1119.888333                     0                      -1
# 2017-11-16    1122.495000                     0                      -1
# 2017-11-17    1124.692500                     0                      -1
# 2017-11-20    1127.405833                     0                      -1
# 2017-11-21    1129.741667                     0                      -1
# 2017-11-22    1132.716667                     0                      -1
# 2017-11-24    1137.989167                     0                      -1
# 2017-11-27    1143.219167                     0                      -1
# 2017-11-28    1148.602500                     0                      -1
# 2017-11-29    1151.591667                     0                      -1
# 2017-11-30    1155.540000                     0                      -1
#
#             %K_80  %K_20
# Unnamed: 0
# 2017-10-26     94     25
# 2017-10-27     94     25
# 2017-10-30     94     25
# 2017-10-31     94     25
# 2017-11-01     94     25
# 2017-11-02     94     25
# 2017-11-03     94     25
# 2017-11-06     94     25
# 2017-11-07     94     25
# 2017-11-08     94     25
# 2017-11-09     94     25
# 2017-11-10     94     25
# 2017-11-13     94     25
# 2017-11-14     94     25
# 2017-11-15     94     25
# 2017-11-16     94     25
# 2017-11-17     94     25
# 2017-11-20     94     25
# 2017-11-21     94     25
# 2017-11-22     94     25
# 2017-11-24     94     25
# 2017-11-27     94     25
# 2017-11-28     94     25
# 2017-11-29     94     25
# 2017-11-30     94     25

# %%
# Visualize exit position relative to close price
exit = faangm_closing_return_df[faangm_closing_return_df['AMZN_stoch_oscl_exit'] == -1]['AMZN'].hvplot.scatter(
    color='red',
    marker='v',
    legend=False,
    ylabel='Price in $',
    xlabel='Time',
    width=1000,
    height=400
)

# Visualize entry position relative to close price
entry = faangm_closing_return_df[faangm_closing_return_df['AMZN_stoch_oscl_exit'] == 1]['AMZN'].hvplot.scatter(
    color='green',
    marker='^',
    legend=False,
    ylabel='Price in $',
    xlabel='Time',
    width=1000,
    height=400
)

# Visualize close price for the investment
security_close = faangm_closing_return_df[['AMZN']].hvplot(
    line_color='lightgray',
    ylabel='Price in $',
    xlabel='Time',
    width=1000,
    height=400
)

# Visualize moving averages
moving_avgs = faangm_closing_return_df[['AMZN_k_component_fast', 'AMZN_d_component_slow',
                                        'AMZN_sma_fast','AMZN_sma_slow',
                                        '%K_80','%K_20']].hvplot(
    ylabel='Price in $',
    xlabel='Time',
    width=1000,
    height=400
)

# Overlay plots
entry_exit_plot = security_close * moving_avgs * entry * exit
entry_exit_plot
# Out:
# :Overlay
#    .Curve.I         :Curve   [Unnamed: 0]   (AMZN)
#    .NdOverlay.I     :NdOverlay   [Variable]
#       :Curve   [Unnamed: 0]   (value)
#    .Scatter.AMZN.I  :Scatter   [Unnamed: 0]   (AMZN)
#    .Scatter.AMZN.II :Scatter   [Unnamed: 0]   (AMZN)

# %%
# ax1 = plt.subplot2grid((80, 400), (0,0), rowspan = 5, colspan = 40)
# ax2 = plt.subplot2grid((80, 400), (50,0), rowspan = 3, colspan = 40)
# ax1.plot(faangm_closing_return_df["AMZN"], color = 'skyblue', label = 'AMZN')
# ax1.plot(faangm_closing_return_df.index, faangm_closing_return_df["buy_price"], marker = '^', color = 'green', markersize = 10, label = 'BUY SIGNAL', linewidth = 0)
# ax1.plot(faangm_closing_return_df.index, faangm_closing_return_df["sell_price"], marker = 'v', color = 'r', markersize = 10, label = 'SELL SIGNAL', linewidth = 0)
# ax1.legend(loc = 'upper left')
# ax1.set_title('AMZN STOCK PRICE')
# ax2.plot(faangm_closing_return_df['AMZN_k_component_fast'], color = 'deepskyblue', linewidth = 1.5, label = '%K')
# ax2.plot(faangm_closing_return_df['AMZN_d_component_slow'], color = 'orange', linewidth = 1.5, label = '%D')
# ax2.axhline(80, color = 'black', linewidth = 1, linestyle = '--')
# ax2.axhline(20, color = 'black', linewidth = 1, linestyle = '--')
# ax2.set_title('AMZN STOCH')
# ax2.legend()
# #ax1.plot(figsize=(20, 20))
# plt.rcParams["figure.figsize"] = (20,3)
# plt.show()

# %%
# Set initial capital
initial_capital = float(1100000)

# Set the share size
share_size = 500

# Take a 500 share position where the dual moving average crossover is 1 (sma_fast is greater than sma_slow)
faangm_closing_return_df['AMZN_position'] = share_size * faangm_closing_return_df['AMZN_stoch_oscl_signal']

# Find the points in time where a 500 share position is bought or sold
faangm_closing_return_df['AMZN_entry_exit_position'] = faangm_closing_return_df['AMZN_position'].diff()

# Multiply share price by entry/exit positions and get the cumulatively sum
faangm_closing_return_df['AMZN_portfolio_holdings'] = faangm_closing_return_df['AMZN'] * faangm_closing_return_df['AMZN_entry_exit_position'].cumsum()

# Subtract the initial capital by the portfolio holdings to get the amount of liquid cash in the portfolio
faangm_closing_return_df['AMZN_portfolio_cash'] = initial_capital - (faangm_closing_return_df['AMZN'] * faangm_closing_return_df['AMZN_entry_exit_position']).cumsum()

# Get the total portfolio value by adding the cash amount by the portfolio holdings (or investments)
faangm_closing_return_df['AMZN_portfolio_total'] = faangm_closing_return_df['AMZN_portfolio_cash'] + faangm_closing_return_df['AMZN_portfolio_holdings']

# Calculate the portfolio daily returns
faangm_closing_return_df['AMZN_portfolio_daily_returns'] = faangm_closing_return_df['AMZN_portfolio_total'].pct_change()

# Calculate the cumulative returns
faangm_closing_return_df['AMZN_portfolio_cumulative_returns'] = (1 + faangm_closing_return_df['AMZN_portfolio_daily_returns']).cumprod() - 1

# Drop all NaN values from the DataFrame
faangm_closing_return_df = faangm_closing_return_df.dropna()

faangm_closing_return_df.to_csv("backtest.csv")

# Print the DataFrame
faangm_closing_return_df.tail(10)
# Out:
#                 AMZN  AMZN_k_period_min  AMZN_k_period_max  \
# Unnamed: 0
# 2021-09-01  3479.580            3186.47            3479.58
# 2021-09-02  3463.400            3186.47            3479.58
# 2021-09-03  3478.770            3186.47            3479.58
# 2021-09-07  3509.140            3186.47            3509.14
# 2021-09-08  3525.690            3186.47            3525.69
# 2021-09-09  3485.300            3186.47            3525.69
# 2021-09-10  3470.390            3186.47            3525.69
# 2021-09-13  3455.960            3186.47            3525.69
# 2021-09-14  3450.055            3199.06            3525.69
# 2021-09-15  3475.380            3265.97            3525.69
#
#             AMZN_k_component_fast  AMZN_d_component_slow  AMZN_sma_fast  \
# Unnamed: 0
# 2021-09-01             100.000000              82.382986      3329.5260
# 2021-09-02              94.479888              86.872346      3357.2190
# 2021-09-03              99.723653              92.566590      3385.1900
# 2021-09-07             100.000000              97.134132      3409.5070
# 2021-09-08             100.000000              99.171934      3431.4720
# 2021-09-09              88.093273              97.470973      3450.0030
# 2021-09-10              83.697895              95.142101      3465.4950
# 2021-09-13              79.444019              92.205533      3476.1860
# 2021-09-14              76.843829              89.686096      3479.0775
# 2021-09-15              80.629139              86.958308      3479.3665
#
#             AMZN_sma_slow  AMZN_stoch_oscl_exit  AMZN_stoch_oscl_signal  \
# Unnamed: 0
# 2021-09-01    3311.535833                     0                       0
# 2021-09-02    3329.989167                     0                       0
# 2021-09-03    3353.119167                     0                       0
# 2021-09-07    3380.008333                    -1                      -1
# 2021-09-08    3407.227500                     0                      -1
# 2021-09-09    3425.505000                     0                      -1
# 2021-09-10    3439.200833                     0                      -1
# 2021-09-13    3452.198333                     0                      -1
# 2021-09-14    3463.413750                     0                      -1
# 2021-09-15    3473.941250                     0                      -1
#
#             %K_80  %K_20  AMZN_position  AMZN_entry_exit_position  \
# Unnamed: 0
# 2021-09-01     94     25              0                       0.0
# 2021-09-02     94     25              0                       0.0
# 2021-09-03     94     25              0                       0.0
# 2021-09-07     94     25           -500                    -500.0
# 2021-09-08     94     25           -500                       0.0
# 2021-09-09     94     25           -500                       0.0
# 2021-09-10     94     25           -500                       0.0
# 2021-09-13     94     25           -500                       0.0
# 2021-09-14     94     25           -500                       0.0
# 2021-09-15     94     25           -500                       0.0
#
#             AMZN_portfolio_holdings  AMZN_portfolio_cash  \
# Unnamed: 0
# 2021-09-01                1739790.0            944778.85
# 2021-09-02                1731700.0            944778.85
# 2021-09-03                1739385.0            944778.85
# 2021-09-07                      0.0           2699348.85
# 2021-09-08                      0.0           2699348.85
# 2021-09-09                      0.0           2699348.85
# 2021-09-10                      0.0           2699348.85
# 2021-09-13                      0.0           2699348.85
# 2021-09-14                      0.0           2699348.85
# 2021-09-15                      0.0           2699348.85
#
#             AMZN_portfolio_total  AMZN_portfolio_daily_returns  \
# Unnamed: 0
# 2021-09-01            2684568.85                      0.001322
# 2021-09-02            2676478.85                     -0.003014
# 2021-09-03            2684163.85                      0.002871
# 2021-09-07            2699348.85                      0.005657
# 2021-09-08            2699348.85                      0.000000
# 2021-09-09            2699348.85                      0.000000
# 2021-09-10            2699348.85                      0.000000
# 2021-09-13            2699348.85                      0.000000
# 2021-09-14            2699348.85                      0.000000
# 2021-09-15            2699348.85                      0.000000
#
#             AMZN_portfolio_cumulative_returns
# Unnamed: 0
# 2021-09-01                           1.440517
# 2021-09-02                           1.433163
# 2021-09-03                           1.440149
# 2021-09-07                           1.453953
# 2021-09-08                           1.453953
# 2021-09-09                           1.453953
# 2021-09-10                           1.453953
# 2021-09-13                           1.453953
# 2021-09-14                           1.453953
# 2021-09-15                           1.453953

# %%
# Visualize exit position relative to total portfolio value
exit = faangm_closing_return_df[faangm_closing_return_df['AMZN_stoch_oscl_exit'] == -1.0]['AMZN_portfolio_total'].hvplot.scatter(
    color='red',
    marker='v',
    legend=False,
    ylabel='Total Portfolio Value',
    width=1000,
    height=400
)

# Visualize entry position relative to total portfolio value
entry = faangm_closing_return_df[faangm_closing_return_df['AMZN_stoch_oscl_exit'] == 1.0]['AMZN_portfolio_total'].hvplot.scatter(
    color='green',
    marker='^',
    legend=False,
    ylabel='Total Portfolio Value',
    width=1000,
    height=400
)

# Visualize total portoflio value for the investment
total_portfolio_value = faangm_closing_return_df[['AMZN_portfolio_total']].hvplot(
    line_color='lightgray',
    ylabel='Total Portfolio Value',
    width=1000,
    height=400
)

# Overlay plots
portfolio_entry_exit_plot = total_portfolio_value * entry * exit
portfolio_entry_exit_plot
# Out:
# :Overlay
#    .Curve.I                         :Curve   [Unnamed: 0]   (AMZN_portfolio_total)
#    .Scatter.AMZN_portfolio_total.I  :Scatter   [Unnamed: 0]   (AMZN_portfolio_total)
#    .Scatter.AMZN_portfolio_total.II :Scatter   [Unnamed: 0]   (AMZN_portfolio_total)

# %%
# Prepare DataFrame for metrics
metrics = [
    'annual_return',
    'cumulative_returns',
    'annual_volatility',
    'sharpe_ratio',
    'sortino_ratio']

columns = ['backtest']

# Initialize the DataFrame with index set to evaluation metrics and column as `Backtest` (just like PyFolio)
#portfolio_evaluation_df = pd.DataFrame(index=metrics, columns=columns)
AMZN_portfolio_evaluation_df = pd.DataFrame({ 'backtest': [np.nan] * 5 }, index=metrics)

AMZN_portfolio_evaluation_df.head()
# Out:
#                     backtest
# annual_return            NaN
# cumulative_returns       NaN
# annual_volatility        NaN
# sharpe_ratio             NaN
# sortino_ratio            NaN

# %%
# List of all the clumn names of the dataframe
list(faangm_closing_return_df.columns)
# Out:
# ['AMZN',
#  'AMZN_k_period_min',
#  'AMZN_k_period_max',
#  'AMZN_k_component_fast',
#  'AMZN_d_component_slow',
#  'AMZN_sma_fast',
#  'AMZN_sma_slow',
#  'AMZN_stoch_oscl_exit',
#  'AMZN_stoch_oscl_signal',
#  '%K_80',
#  '%K_20',
#  'AMZN_position',
#  'AMZN_entry_exit_position',
#  'AMZN_portfolio_holdings',
#  'AMZN_portfolio_cash',
#  'AMZN_portfolio_total',
#  'AMZN_portfolio_daily_returns',
#  'AMZN_portfolio_cumulative_returns']

# %%
# Calculate cumulative return
AMZN_portfolio_evaluation_df.loc['cumulative_returns'] = faangm_closing_return_df['AMZN_portfolio_cumulative_returns'][-1]

# Calculate annualized return
AMZN_portfolio_evaluation_df.loc['annual_return'] = (
    faangm_closing_return_df['AMZN_portfolio_daily_returns'].mean() * 252
)

# Calculate annual volatility
AMZN_portfolio_evaluation_df.loc['annual_volatility'] = (
    faangm_closing_return_df['AMZN_portfolio_daily_returns'].std() * np.sqrt(252)
)

# Calculate Sharpe Ratio
AMZN_portfolio_evaluation_df.loc['sharpe_ratio'] = (
    faangm_closing_return_df['AMZN_portfolio_daily_returns'].mean() * 252) / (
    faangm_closing_return_df['AMZN_portfolio_daily_returns'].std() * np.sqrt(252)
)

# Calculate Downside Return
sortino_ratio_df = faangm_closing_return_df[['AMZN_portfolio_daily_returns']].copy()
sortino_ratio_df.loc[:,'downside_returns'] = 0

target = 0
mask = sortino_ratio_df['AMZN_portfolio_daily_returns'] < target
sortino_ratio_df.loc[mask, 'downside_returns'] = sortino_ratio_df['AMZN_portfolio_daily_returns']**2

# Calculate Sortino Ratio
down_stdev = np.sqrt(sortino_ratio_df['downside_returns'].mean()) * np.sqrt(252) # Annualizing
expected_return = sortino_ratio_df['AMZN_portfolio_daily_returns'].mean() * 252 # Annualizing
sortino_ratio = expected_return/down_stdev

AMZN_portfolio_evaluation_df.loc['sortino_ratio'] = sortino_ratio
AMZN_portfolio_evaluation_df.head()
# Out:
#                     backtest
# annual_return       0.243157
# cumulative_returns  1.453953
# annual_volatility   0.150418
# sharpe_ratio        1.616544
# sortino_ratio       2.588355
